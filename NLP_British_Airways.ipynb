# %%
# !pip install requests beautifulsoup4 lxml pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
 # Replace with the URL you want to scrape
url =  'https://www.airlinequality.com/airline-reviews/british-airways'
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Example: Extract all paragraph texts
paragraphs = soup.find_all('p')
for para in paragraphs:
    print(para.get_text())
# Out:
# British Airways is the flag carrier of the United Kingdom, with its main hub being at London Heathrow Airport where it operates from Terminal 5 and Terminal 3. The airline also has substantial operations from Gatwick Airport. British Airways is a member of Onweworld alliance, and part of International Airlines Group (IAG).
# British Airways offers First Class on many long haul routes operated by widebody aircraft (Boeing 747-400, Boeing 777, Boeing 787 and the A380). Most aircraft have 14 flat-bed seats in First Class, and 8 seats on the Boeing 787-9.
#
# Flat bed seat / suite
# In-seat &/or USB power
# Onboard WiFi
# Audio / video on demand
# On demand dining
# Fine wines & beverage service
# Pillows & duvet / blanket
# Pyjamas / Sleepsuit
# Amenity kit
# ...

# %%
# !pip install html5lib
# Out:
# ...
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    -------------- ------------------------- 41.0/112.2 kB ? eta -:--:--
#    -------------- ------------------------- 41.0/112.2 kB ? eta -:--:--
#    -------------- ------------------------- 41.0/112.2 kB ? eta -:--:--
#    -------------- ------------------------- 41.0/112.2 kB ? eta -:--:--
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.airlinequality.com/airline-reviews/british-airways'  # Replace with actual review page URL
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the ratings table
ratings_table = soup.find('table', class_='review-ratings')

# Dictionary to store ratings
ratings = {}

# Extract rating categories and their values
for row in ratings_table.find_all('tr'):
    category_td = row.find('td', class_='review-rating-header')
    stars_td = row.find('td', class_='review-rating-stars')
    
    if category_td and stars_td:
        category = category_td.get_text(strip=True)
        stars = stars_td.find_all('span', class_='star fill')
        
        # Number of filled stars
        rating_value = len(stars)
        
        # Store in dictionary
        ratings[category] = rating_value

# Print the extracted ratings
for category, rating in ratings.items():
    print(f"{category}: {rating} stars")
# Out:
# Food & Beverages: 3 stars
# Inflight Entertainment: 3 stars
# Seat Comfort: 3 stars
# Staff Service: 3 stars
# Value for Money: 3 stars

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page containing the ratings
url = 'https://www.airlinequality.com/airline-reviews/british-airways'  # Replace with the actual URL

# Send a GET request to fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the rating totals section
rating_totals = soup.find('div', class_='rating-totals')

# Extract the total number of reviews
review_count_span = rating_totals.find('span', itemprop='reviewCount')
review_count = review_count_span.get_text(strip=True) if review_count_span else 'N/A'

# Extract the average rating value and best rating
rating_value_span = rating_totals.find('span', itemprop='ratingValue')
best_rating_span = rating_totals.find('span', itemprop='bestRating')
rating_value = rating_value_span.get_text(strip=True) if rating_value_span else 'N/A'
best_rating = best_rating_span.get_text(strip=True) if best_rating_span else 'N/A'

# Extract the Skytrax rating image URL
skytrax_img = rating_totals.find('img', class_='skytrax-rating')
skytrax_img_src = skytrax_img['src'] if skytrax_img else 'N/A'

# Print the extracted information
print(f"Total Reviews: {review_count}")
print(f"Average Rating: {rating_value}/{best_rating}")

#print(f"Skytrax Rating Image URL: {skytrax_img_src}")
# Out:
# Total Reviews: 3832
# Average Rating: 5/10

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page containing the ratings (replace with actual URL)
url = 'https://www.airlinequality.com/airline-reviews/british-airways'

# Send a GET request to fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the section with reviews
review_sections = soup.find_all('div', class_='text_content')

# Iterate over each review section to extract details
for review_section in review_sections:
    # Extract review body
    review_body = review_section.get_text(strip=True)
    print(f"Review Body:\n{review_body}\n")

    # Find ratings within the same review section
    review_stats = review_section.find_next_sibling('div', class_='review-stats')
    if review_stats:
        rating_table = review_stats.find('table', class_='review-ratings')
        if rating_table:
            ratings = {}
            rating_elements = rating_table.find_all('tr')

            for element in rating_elements:
                header = element.find('td', class_='review-rating-header')
                value = element.find('td', class_='review-value')

                if header and value:
                    header_text = header.get_text(strip=True)
                    value_text = value.get_text(strip=True)

                    if header_text in ['Seat Comfort', 'Cabin Staff Service', 'Food & Beverages', 'Ground Service', 'Value For Money']:
                        rating_stars = element.find('td', class_='review-rating-stars')
                        if rating_stars:
                            stars = rating_stars.find_all('span', class_='star')
                            rating = sum(1 for star in stars if 'fill' in star.get('class', []))
                            ratings[header_text] = rating

            # Extract recommendation
            recommended = review_stats.find('td', class_='review-value rating-no')
            recommended_text = recommended.get_text(strip=True) if recommended else 'N/A'

            # Print the extracted ratings
            print("Ratings:")
            for category, rating in ratings.items():
                print(f"{category}: {rating} out of 5")
            print(f"Recommended: {recommended_text}\n")
# Out:
# Review Body:
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page containing the ratings (replace with actual URL)
url = 'https://www.airlinequality.com/airline-reviews/british-airways'

# Send a GET request to fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the review ratings table
rating_table = soup.find('table', class_='review-ratings')

# Initialize a dictionary to store ratings and headers
ratings = {}

# Iterate through each row in the table
for row in rating_table.find_all('tr'):
    # Extract the header and value cells
    header = row.find('td', class_='review-rating-header')
    stars = row.find('td', class_='review-rating-stars')
    value = row.find('td', class_='review-value')
    
    if header:
        header_text = header.get_text(strip=True)
        
        if stars:
            # Count the number of filled stars
            star_elements = stars.find_all('span', class_='star')
            rating = sum(1 for star in star_elements if 'fill' in star.get('class', []))
            ratings[header_text] = f"{rating} out of 5"
        elif value:
            # For non-star ratings
            value_text = value.get_text(strip=True)
            ratings[header_text] = value_text

# Print the extracted headers and ratings
print("Review Ratings:")
for category, detail in ratings.items():
    print(f"{category}: {detail}")
# Out:
# Review Ratings:
# Food & Beverages: 3 out of 5
# Inflight Entertainment: 3 out of 5
# Seat Comfort: 3 out of 5
# Staff Service: 3 out of 5
# Value for Money: 3 out of 5

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page containing the reviews (replace with actual URL)
url = 'https://www.airlinequality.com/airline-reviews/british-airways'

# Send a GET request to fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find all review sections
review_sections = soup.find_all('div', class_='text_content')

# Iterate over each review section to extract details
for review_section in review_sections:
    # Extract review body
    review_body = review_section.get_text(strip=True)
    print(f"Review Body:\n{review_body}\n")

    # Find the ratings and recommendation within the same review section
    review_stats = review_section.find_next_sibling('div', class_='review-stats')
    if review_stats:
        rating_table = review_stats.find('table', class_='review-ratings')
        if rating_table:
            ratings = {}
            rating_elements = rating_table.find_all('tr')

            for element in rating_elements:
                header = element.find('td', class_='review-rating-header')
                stars = element.find('td', class_='review-rating-stars')
                value = element.find('td', class_='review-value')

                if header:
                    header_text = header.get_text(strip=True)
                    
                    if stars:
                        # Count the number of filled stars
                        star_elements = stars.find_all('span', class_='star')
                        rating = sum(1 for star in star_elements if 'fill' in star.get('class', []))
                        ratings[header_text] = f"{rating} out of 5"
                    elif value:
                        # Handle non-star ratings
                        value_text = value.get_text(strip=True)
                        ratings[header_text] = value_text

            # Extract recommendation
            recommended = review_stats.find('td', class_='review-value rating-no')
            recommended_text = recommended.get_text(strip=True) if recommended else 'N/A'

            # Print the extracted ratings and recommendation
            print("Ratings:")
            for category, rating in ratings.items():
                print(f"{category}: {rating}")
            print(f"Recommended: {recommended_text}\n")
# Out:
# Review Body:
# ...

# %%
import html5lib
print(html5lib.__version__)
# Out:
# 1.1

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Base URL of the page containing the reviews (replace with actual base URL)
base_url = 'https://www.airlinequality.com/airline-reviews/british-airways'

# Define the number of pages to scrape
total_pages = 383

# List to hold review data
reviews_data = []

# Iterate through each page
for page in range(1, total_pages + 1):
    # Construct the URL for the current page
    if page == 1:
        url = base_url
    else:
        url = f'{base_url}/page/{page}/'

    # Send a GET request to fetch the page content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all review sections on the current page
    review_sections = soup.find_all('div', class_='text_content')

    # Iterate over each review section to extract details
    for review_section in review_sections:
        # Extract review body
        review_body = review_section.get_text(strip=True)

        # Find the ratings and recommendation within the same review section
        review_stats = review_section.find_next_sibling('div', class_='review-stats')
        if review_stats:
            rating_table = review_stats.find('table', class_='review-ratings')
            if rating_table:
                ratings = {}
                rating_elements = rating_table.find_all('tr')

                for element in rating_elements:
                    header = element.find('td', class_='review-rating-header')
                    stars = element.find('td', class_='review-rating-stars')
                    value = element.find('td', class_='review-value')

                    if header:
                        header_text = header.get_text(strip=True)

                        if stars:
                            # Count the number of filled stars
                            star_elements = stars.find_all('span', class_='star')
                            rating = sum(1 for star in star_elements if 'fill' in star.get('class', []))
                            ratings[header_text] = f"{rating} out of 5"
                        elif value:
                            # Handle non-star ratings
                            value_text = value.get_text(strip=True)
                            ratings[header_text] = value_text

                # Extract recommendation
                recommended = review_stats.find('td', class_='review-value rating-no')
                recommended_text = recommended.get_text(strip=True) if recommended else 'N/A'

                # Append extracted data to the list
                reviews_data.append({
                    'Review Body': review_body,
                    'Seat Comfort': ratings.get('Seat Comfort', 'N/A'),
                    'Cabin Staff Service': ratings.get('Cabin Staff Service', 'N/A'),
                    'Food & Beverages': ratings.get('Food & Beverages', 'N/A'),
                    'Ground Service': ratings.get('Ground Service', 'N/A'),
                    'Value For Money': ratings.get('Value For Money', 'N/A'),
                    'Recommended': recommended_text
                })

# Write the data to a CSV file
csv_file = 'airline_reviews.csv'
csv_columns = ['Review Body', 'Seat Comfort', 'Cabin Staff Service', 'Food & Beverages', 'Ground Service', 'Value For Money', 'Recommended']

with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=csv_columns)
    writer.writeheader()
    writer.writerows(reviews_data)

print(f"Data has been exported to {csv_file}")
# Out:
# Data has been exported to airline_reviews.csv

# %%
# Define the path to the CSV file
file_path = r'C:\Users\User\airline_reviews.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#                                          Review Body Seat Comfort  \
# 0  Not Verified|  I flew internationally for the ...   3 out of 5
# 1  ✅Trip Verified| BA, after subsequent delays an...   3 out of 5
# 2  Not Verified|   It is embarrassing to have the...   1 out of 5
# 3  ✅Trip Verified| Flight cancelled due to bad we...   3 out of 5
# 4  ✅Trip Verified|  British Airways oversold my L...   1 out of 5
#
#   Cabin Staff Service Food & Beverages Ground Service Value For Money  \
# 0          3 out of 5              NaN     1 out of 5      1 out of 5
# 1          1 out of 5       1 out of 5     1 out of 5      1 out of 5
# 2          3 out of 5       3 out of 5     1 out of 5      1 out of 5
# 3          5 out of 5       4 out of 5     5 out of 5      4 out of 5
# 4          1 out of 5              NaN     1 out of 5      1 out of 5
#
#   Recommended
# 0          no
# 1          no
# 2          no
# 3         NaN
# 4          no

# %%
import pandas as pd

# Load the scraped CSV file
csv_file = 'airline_reviews.csv'
df = pd.read_csv(csv_file)

# Display the first few rows of the dataframe
print("Original Data:")
print(df.head())

# Cleaning steps:

# 1. Remove leading and trailing whitespaces from all column names
df.columns = df.columns.str.strip()

# 2. Fill missing values or handle them appropriately
# - For numeric ratings, replace NaNs with 'Not Rated' or a placeholder
df.fillna({
    'Seat Comfort': 'Not Rated',
    'Cabin Staff Service': 'Not Rated',
    'Food & Beverages': 'Not Rated',
    'Ground Service': 'Not Rated',
    'Value For Money': 'Not Rated',
    'Recommended': 'Unknown'
}, inplace=True)

# 3. Normalize the text data (e.g., remove extra spaces, convert to lowercase)
df['Review Body'] = df['Review Body'].str.strip()
df['Review Body'] = df['Review Body'].str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with single space

# 4. Ensure that categorical fields are consistent
df['Recommended'] = df['Recommended'].str.strip().str.lower().replace({
    'yes': 'Yes',
    'no': 'No',
    'unknown': 'Unknown'
})

# 5. Save the cleaned dataframe to a new CSV file
cleaned_csv_file = 'cleaned_airline_reviews.csv'
df.to_csv(cleaned_csv_file, index=False)

print(f"Data cleaned and saved to {cleaned_csv_file}")
# Out:
# Original Data:
#                                          Review Body Seat Comfort  \
# 0  Not Verified|  I flew internationally for the ...   3 out of 5
# 1  ✅Trip Verified| BA, after subsequent delays an...   3 out of 5
# 2  Not Verified|   It is embarrassing to have the...   1 out of 5
# 3  ✅Trip Verified| Flight cancelled due to bad we...   3 out of 5
# 4  ✅Trip Verified|  British Airways oversold my L...   1 out of 5
#
#   Cabin Staff Service Food & Beverages Ground Service Value For Money  \
# 0          3 out of 5              NaN     1 out of 5      1 out of 5
# 1          1 out of 5       1 out of 5     1 out of 5      1 out of 5
# 2          3 out of 5       3 out of 5     1 out of 5      1 out of 5
# 3          5 out of 5       4 out of 5     5 out of 5      4 out of 5
# 4          1 out of 5              NaN     1 out of 5      1 out of 5
#
#   Recommended
# 0          no
# 1          no
# 2          no
# 3         NaN
# 4          no
# ...

# %%
import pandas as pd

# Load the cleaned CSV file
cleaned_csv_file = 'cleaned_airline_reviews.csv'
df_cleaned = pd.read_csv(cleaned_csv_file)

# Display the first few rows of the cleaned dataframe
print("Cleaned Data:")
print(df_cleaned.head())
# Out:
# Cleaned Data:
#                                          Review Body Seat Comfort  \
# 0  Not Verified| I flew internationally for the f...   3 out of 5
# 1  ✅Trip Verified| BA, after subsequent delays an...   3 out of 5
# 2  Not Verified| It is embarrassing to have the w...   1 out of 5
# 3  ✅Trip Verified| Flight cancelled due to bad we...   3 out of 5
# 4  ✅Trip Verified| British Airways oversold my LH...   1 out of 5
#
#   Cabin Staff Service Food & Beverages Ground Service Value For Money  \
# 0          3 out of 5        Not Rated     1 out of 5      1 out of 5
# 1          1 out of 5       1 out of 5     1 out of 5      1 out of 5
# 2          3 out of 5       3 out of 5     1 out of 5      1 out of 5
# 3          5 out of 5       4 out of 5     5 out of 5      4 out of 5
# 4          1 out of 5        Not Rated     1 out of 5      1 out of 5
#
#   Recommended
# 0          No
# 1          No
# 2          No
# 3     Unknown
# 4          No

# %%
# Example: Extract reviews and ratings
    reviews = [review.get_text(strip=True) for review in soup.find_all('div', class_='review-text')]
    ratings = [rating.get_text(strip=True) for rating in soup.find_all('span', class_='review-rating')]

    # Debugging: Print lengths and samples
    print(f"Number of reviews: {len(reviews)}")
    print(f"Number of ratings: {len(ratings)}")
    print(f"Sample reviews: {reviews[:5]}")
    print(f"Sample ratings: {ratings[:5]}")

    # Ensure lists are the same length
    min_length = min(len(reviews), len(ratings))
    reviews = reviews[:min_length]
    ratings = ratings[:min_length]

    # Create a DataFrame
    data = {
        'Review': reviews,
        'Rating': ratings
    }
    df = pd.DataFrame(data)

    # Save to CSV
    df.to_csv('customer_reviews.csv', index=False)

    print("Data scraped and saved to 'customer_reviews.csv'")

except requests.RequestException as e:
    print(f"Error fetching the page: {e}")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#   Cell In[43], line 2
#     reviews = [review.get_text(strip=True) for review in soup.find_all('div', class_='review-text')]
#     ^
# IndentationError: unexpected indent

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_reviews_from_page(url):
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')

    reviews = [review.get_text(strip=True) for review in soup.find_all('div', class_='review-text')]
    ratings = [rating.get_text(strip=True) for rating in soup.find_all('span', class_='review-rating')]
    return reviews, ratings

def scrape_all_reviews(base_url, num_pages):
    all_reviews = []
    all_ratings = []
    
    for page in range(1, num_pages + 1):
        url = f"{base_url}?page={page}"
        reviews, ratings = fetch_reviews_from_page(url)
        all_reviews.extend(reviews)
        all_ratings.extend(ratings)

    # Ensure lists are the same length
    min_length = min(len(all_reviews), len(all_ratings))
    all_reviews = all_reviews[:min_length]
    all_ratings = all_ratings[:min_length]

    return all_reviews, all_ratings

# Define base URL and number of pages to scrape
base_url = 'https://www.airlinequality.com/airline-reviews/british-airways'  # Replace with your target URL
num_pages = 5  # Adjust as needed

try:
    reviews, ratings = scrape_all_reviews(base_url, num_pages)

    # Create a DataFrame
    data = {
        'Review': reviews,
        'Rating': ratings
    }
    df = pd.DataFrame(data)

    # Save to CSV
    df.to_csv('customer_reviews.csv', index=False)

    print("Data scraped and saved to 'customer_reviews.csv'")

except requests.RequestException as e:
    print(f"Error fetching the page: {e}")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data scraped and saved to 'customer_reviews.csv'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_reviews_from_page(url):
    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')

    reviews = [review.get_text(strip=True) for review in soup.find_all('div', class_='review-text')]
    ratings = [rating.get_text(strip=True) for rating in soup.find_all('span', class_='review-rating')]
    return reviews, ratings

def scrape_all_reviews(base_url, num_pages):
    all_reviews = []
    all_ratings = []
    
    for page in range(1, num_pages + 1):
        url = f"{base_url}?page={page}"
        reviews, ratings = fetch_reviews_from_page(url)
        all_reviews.extend(reviews)
        all_ratings.extend(ratings)

    # Ensure lists are the same length
    min_length = min(len(all_reviews), len(all_ratings))
    all_reviews = all_reviews[:min_length]
    all_ratings = all_ratings[:min_length]

    return all_reviews, all_ratings

# Define base URL and number of pages to scrape
base_url = 'https://www.airlinequality.com/airline-reviews/british-airways'  # Replace with your target URL
num_pages = 5  # Adjust as needed

try:
    reviews, ratings = scrape_all_reviews(base_url, num_pages)

    # Create a DataFrame
    data = {
        'Review': reviews,
        'Rating': ratings
    }
    df = pd.DataFrame(data)

    # Save to CSV
    df.to_csv('customer_reviews.csv', index=False)

    print("Data scraped and saved to 'customer_reviews.csv'")

except requests.RequestException as e:
    print(f"Error fetching the page: {e}")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data scraped and saved to 'customer_reviews.csv'

# %%
import os

# Display the current working directory
print("Current Working Directory:", os.getcwd())

# Construct the path for the CSV file
csv_path = os.path.join(os.getcwd(), 'customer_reviews.csv')
print("CSV File Path:", csv_path)
# Out:
# Current Working Directory: C:\Users\User
# CSV File Path: C:\Users\User\customer_reviews.csv

# %%
# Define the path to the CSV file
file_path = r'C:\Users\User\customer_reviews.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
# Empty DataFrame
# Columns: [Review, Rating]
# Index: []

# %%
print(df.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 print(df.iloc[0])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
# ...

# %%
print(df.loc[0, 'Review'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(df.loc[0, 'Review'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
# ...

# %%
def fetch_reviews_from_page(url):
    """Fetch reviews from a single page and extract specific categories and ratings."""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Ensure the request was successful
        soup = BeautifulSoup(response.text, 'html.parser')

        # Print the HTML for debugging
        print(soup.prettify())

        # Extract reviews and ratings for each category
        data = []
        reviews = soup.find_all('div', class_='review')  # Adjust the class name as needed
        
        for review in reviews:
            # Extract details for each category
            try:
                # Extract category ratings from table
                ratings_table = review.find('table', class_='review-ratings')
                if ratings_table:
                    ratings = ratings_table.find_all('tr')
                    
                    # Initialize category ratings
                    seat_comfort = cabin_staff = food_beverages = entertainment = ground_services = value_money = recommended = None
                    
                    for rating in ratings:
                        cells = rating.find_all('td')
                        if len(cells) == 2:
                            category = cells[0].get_text(strip=True)
                            stars = cells[1].find_all('span', class_='star')
                            rating_score = extract_rating(stars)

                            if 'Seat Comfort' in category:
                                seat_comfort = rating_score
                            elif 'Cabin Staff Service' in category:
                                cabin_staff = rating_score
                            elif 'Food & Beverages' in category:
                                food_beverages = rating_score
                            elif 'Inflight Entertainment' in category:
                                entertainment = rating_score
                            elif 'Ground Service' in category:
                                ground_services = rating_score
                            elif 'Value For Money' in category:
                                value_money = rating_score
                            elif 'Recommended' in category:
                                recommended = cells[1].get_text(strip=True).strip()

                    # Append extracted data
                    data.append({
                        'Seat Comfort': seat_comfort,
                        'Cabin Staff Service': cabin_staff,
                        'Food and Beverages': food_beverages,
                        'Inflight Entertainment': entertainment,
                        'Ground Services': ground_services,
                        'Value for Money': value_money,
                        'Recommended': recommended
                    })
                else:
                    print("No ratings table found in review")
            except Exception as e:
                print(f"Error processing review: {e}")

        print(f"Extracted {len(data)} reviews from {url}")
        return data
    except requests.RequestException as e:
        print(f"Request error fetching {url}: {e}")
        return []
    except Exception as e:
        print(f"General error fetching {url}: {e}")
        return []
